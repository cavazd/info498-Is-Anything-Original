# %% [markdown]
# # Get Film Data From Wikipedia

# %%
# %pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from wikipedia) (4.11.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from wikipedia) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->wikipedia) (2.3.2.post1)
# Installing collected packages: wikipedia
#   Running setup.py install for wikipedia: started
#   Running setup.py install for wikipedia: finished with status 'done'
# Successfully installed wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: wikipedia is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup
import wikipedia as wiki
import pandas as pd
import re

def get_wiki_page(title):
    """
    Get the wikipedia page given a title

    NOTE: From https://github.com/openai/openai-cookbook/blob/main/examples/fine-tuned_qa/olympics-1-collect-data.ipynb
    """
    try:
        return wiki.WikipediaPage(title)
    except wiki.exceptions.DisambiguationError as e:
        return wiki.WikipediaPage(e.options[0])
    except wiki.exceptions.PageError as e:
        return None

# %%
# get wikipedia pages
pages = [get_wiki_page(page) for page in ["List_of_film_remakes_(A–M)", "List_of_film_remakes_(N-Z)"]]
# get beautiful soup of page
pages = [BeautifulSoup(page.html(), "html.parser") for page in pages]
# get all h2 values from page
pages = [page.find_all('h2')[:-2] for page in pages]

# %%
def get_rows(header):
    rows = []
    table = header.find_next_sibling()
    og, remake = '', ''
    for row in table.find_all('tr')[1:]: # 1:end is to skip header
        og, remake = tuple([s.text.strip() for s in row.find_all('td')[:2]])
        rows.append({'header': header.text.replace('[edit]', ''), 'original': og, 'remake': remake})
    return rows

# %%
all_rows = []
for h2s in pages:
    for header in h2s:
        all_rows += get_rows(header)
        
og_remake_ref_df = pd.DataFrame(all_rows)

# %% [markdown]
# ## Create All Movies DataFrame

# %%
"""
NOTE: Code written with assistance from ChatGPT

Prompt: Write me the python code to split a series of strings into a list using regex with the following pattern: open parenthesis, 
any number of digits, closed parenthesis. I want to split by this value but keep the content within the parenthesis
"""
def split_remakes(remake):
    pattern = r'(?:\((\d+)\))'
    result = [res.strip() for res in re.split(pattern, remake)][:-1]

    return result

# %%
# create dataframe for all movies
all_movies = []
for remake_row in og_remake_ref_df.remake.apply(split_remakes).tolist():
    for i in range(len(remake_row) // 2):
        all_movies.append({
            'movie': remake_row[i*2].strip(),
            'year': remake_row[(i*2)+1].strip(),
            'status': 'remake'
        })

for og_row in og_remake_ref_df.original.str.split('('):
    all_movies.append({
        'movie': og_row[0].strip(),
        'year': og_row[-1].replace(')', '').strip(),
        'status': 'original'
    })

all_movies_df = pd.DataFrame(all_movies)

# %% [markdown]
# # Get Data From IMDB

# %%
import requests
import time

# %%
def get_movie_info(title, year):
    api_key = '716978917b3565e92ac410463f95122c'
    url = f"https://api.themoviedb.org/3/search/movie?query={title}&include_adult=true&page=1&year={year}&api_key={api_key}"
    res = requests.get(url)
    # hope the first value is the movie we are looking for
    res = res.json()['results'][0]
    return {
        'original_language': res['original_language'],
        'original_title': res['original_title'],
        'overview': res['overview'],
        'popularity': res['popularity'],
        'release_date': res['release_date'],
        'vote_average': res['vote_average'],
        'vote_count': res['vote_count']
    }

# %%
extended_info = []
for _, movie in all_movies_df.iterrows():
    time.sleep(0.4)
    title, year, status = tuple(movie)
    try:
        movie_info = get_movie_info(title, year)
    except:
        print('Error occured')
        print(movie)
        movie_info = {
            'original_language': None,
            'original_title': None,
            'overview': None,
            'popularity': None,
            'release_date': None,
            'vote_average': None,
            'vote_count': None
        }
    movie_info['movie'] = title
    movie_info['year'] = year
    movie_info['status'] = status
    extended_info.append(movie_info)
# Out:
# Error occured
# movie      Aaina
# year        2013
# status    remake
# Name: 11, dtype: object
# Error occured
# movie     Nee Bareda Kadambari
# year                      1985
# status                  remake
# Name: 13, dtype: object
# Error occured
# movie     The Cat and the Canary
# year                        1979
# status                    remake
# Name: 103, dtype: object
# Error occured
# movie     Memoirs of a Murderer aka 22-nenme no kokuhaku...
# year                                                   2017
# status                                               remake
# Name: 122, dtype: object
# Error occured
# movie     Yugandhar
# year           1979
# status       remake
# Name: 157, dtype: object
# Error occured
# movie     Shobhraj
# year          1986
# status      remake
# Name: 159, dtype: object
# Error occured
# movie     Doraemon: Nobita and the Birth of Japan 2016
# year                                              2016
# status                                          remake
# Name: 164, dtype: object
# Error occured
# movie     Frank Herbert's Dune
# year                      2000
# status                  remake
# Name: 174, dtype: object
# Error occured
# movie     Dune (2021 film)\nDune: Part Two
# year                                  2023
# status                              remake
# Name: 175, dtype: object
# Error occured
# movie     The Long Hot Summer
# year                     1985
# status                 remake
# Name: 356, dtype: object
# Error occured
# movie     The Legend of Maula Jatt
# year                          2021
# status                      remake
# Name: 363, dtype: object
# Error occured
# movie     Miracle in Cell No. 7 (Philippine remake)
# year                                           2019
# status                                       remake
# Name: 387, dtype: object
# Error occured
# movie     Miracle in Cell No. 7 (Turkish remake)
# year                                        2019
# status                                    remake
# Name: 388, dtype: object
# Error occured
# movie     Shankar Dada M.B.B.S.
# year                       2004
# status                   remake
# Name: 406, dtype: object
# Error occured
# movie     Vasool Raja M.B.B.S.
# year                      2004
# status                  remake
# Name: 407, dtype: object
# Error occured
# movie     Uppi Dada MBBS
# year                2006
# status            remake
# Name: 408, dtype: object
# Error occured
# movie     Something's Got to Give (unfinished)
# year                                      1962
# status                                  remake
# Name: 414, dtype: object
# Error occured
# movie     Neenello Naanalle
# year                   2006
# status               remake
# Name: 446, dtype: object
# Error occured
# movie     The One Million Pound Note
# year                            1954
# status                        remake
# Name: 458, dtype: object
# Error occured
# movie     One Missed Call
# year                 2007
# status             remake
# Name: 460, dtype: object
# Error occured
# movie     Pati Patni Aur Tawaif
# year                       1990
# status                   remake
# Name: 469, dtype: object
# Error occured
# movie     Pathfinder
# year            2006
# status        remake
# Name: 474, dtype: object
# Error occured
# movie     Song at Midnight
# year                  1931
# status              remake
# Name: 480, dtype: object
# Error occured
# movie     Ihr erstes Rendezvous [de]
# year                            1955
# status                        remake
# Name: 504, dtype: object
# Error occured
# movie     Raja Pakistani
# year                1997
# status            remake
# Name: 512, dtype: object
# Error occured
# movie     The Room remake
# year                 2023
# status             remake
# Name: 527, dtype: object
# Error occured
# movie     The Sun Also Rises
# year                    1984
# status                remake
# Name: 580, dtype: object
# Error occured
# movie     Perfect Number aka Yong-eui-ja X
# year                                  2012
# status                              remake
# Name: 581, dtype: object
# Error occured
# movie     Baghdad Thirudan
# year                  1960
# status              remake
# Name: 596, dtype: object
# Error occured
# movie     Victor and Victoria
# year                     1957
# status                 remake
# Name: 629, dtype: object
# Error occured
# movie     Ulta Palta 69
# year               2007
# status           remake
# Name: 632, dtype: object
# Error occured
# movie     Beautiful Accident aka Mei hao de yi wai
# year                                          2017
# status                                      remake
# Name: 659, dtype: object
# Error occured
# movie     Confession of Murder aka Naega salinbeomida
# year                                             2012
# status                                       original
# Name: 760, dtype: object
# Error occured
# movie      Dehleez
# year          1983
# status    original
# Name: 766, dtype: object
# Error occured
# movie     Haq Mehar
# year           1985
# status     original
# Name: 859, dtype: object
# Error occured
# movie     Happy Days in Aranjuez
# year                        1933
# status                  original
# Name: 861, dtype: object
# Error occured
# movie     The Humpbacked Horse
# year                      1947
# status                original
# Name: 886, dtype: object
# Error occured
# movie     Kolamba Sanniya
# year                 1976
# status           original
# Name: 925, dtype: object
# Error occured
# movie     The Land That Time Forgot
# year                           1975
# status                     original
# Name: 933, dtype: object
# Error occured
# movie     Naukar Wohti Da
# year                 1974
# status           original
# Name: 1007, dtype: object
# Error occured
# movie     The One Million Pound Note
# year                            1916
# status                      original
# Name: 1029, dtype: object
# Error occured
# movie      La Otra
# year          1945
# status    original
# Name: 1034, dtype: object
# Error occured
# movie     Bazar e Husan
# year               1988
# status         original
# Name: 1038, dtype: object
# Error occured
# movie     A Precocious Girl
# year                   1934
# status             original
# Name: 1062, dtype: object
# Error occured
# movie     Suspect X aka Yôgisha X no kenshin
# year                                    2008
# status                              original
# Name: 1127, dtype: object
# Error occured
# movie     Thunderball
# year             1973
# status       original
# Name: 1149, dtype: object
# Error occured
# movie     Wonderful Nightmare aka Misseu waipeu
# year                                       2015
# status                                 original
# Name: 1189, dtype: object
# Error occured
# movie     World on a Wire
# year                 1973
# status           original
# Name: 1190, dtype: object

# %%
extended_info_df = pd.DataFrame(extended_info)

# %%
og_remake_ref_df.to_csv('og_remake_ref.csv', index=False)
extended_info_df.to_csv('extended_info.csv', index=False)
